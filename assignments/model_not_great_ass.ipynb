# %% [markdown]
# *11 Feb 2021, Julian Mak (whatever with copyright, do what you want with this)
#
# ### As part of material for OCES 3301 "Data Analysis in Ocean Sciences" delivered at HKUST
#
# For the latest version of the material, go to the public facing [GitHub](https://github.com/julianmak/academic-notes/tree/master/OCES3301_data_analysis_ocean) page.

# %% [markdown]
# # Model assignment hand-in (not great version): for the logistic map example
#
# The following is my take on what would be counted as a not great attempt at an assignment. Compare this with the attempt given in the other model assignment.
#
# > NOTE: I went slightly overboard, and this attempt would be a borderline fail attempt I would imagine.

# %% [markdown]
# --------

# %% [markdown]
# The logistic map is x_n+1 = r x_n (1 - x_n). Assignment here is to look at the behaviours of this.

# %%
import numpy as np
import matplotlib.pyplot as plt

def logistic_map(x0, r, generation=100):
    """
    subroutine to iterate on the logistic map
    
    x(n+1) = r * x(n) * (1.0 - x(n)) = r * x(n) - r * x(n)**2,
    
    which is a simple model for population growth (r * x(n)) and death (- r * x(n)**2)
      
    returns an array, need to specify 
        initial condition x0 (between 0 and 1, interpreted as a population percentage)
        ratio r (any positive number really)
    
    optional argument
        number of generations (default is 100)
    """
    
    x_out = np.zeros(generation+1)
    x_out[0] = x0
    for i in range(generation):
        x_out[i+1] = r * x_out[i] * (1.0 - x_out[i])

    return x_out

# %% [markdown]
# When r is small solutions go to zero.

# %%
x0 = 0.5

ax = plt.axes()
ax.plot(logistic_map(x0, 0.5))

# %% [markdown]
# For r bigger it doesn't go to zero.

# %%
x0 = 0.5

ax = plt.axes()
ax.plot(logistic_map(x0, 1.5))

# %% [markdown]
# Sometimes you get wriggling behaviour.

# %%
x0 = 0.5

ax = plt.axes()
ax.plot(logistic_map(x0, 2.4))

# %% [markdown]
# And there are cases where you get more wriggling behaviour.

# %%
x0 = 0.5

ax = plt.axes()
ax.plot(logistic_map(x0, 3.5))

# %% [markdown]
# Below graph below shows cahos.

# %%
x0 = 0.5

ax = plt.axes()
ax.plot(logistic_map(x0, 3.7))

# %% [markdown]
# We have investiged here that the equatons above has many different behaviors, which represnts phyotoplankton population. Numerical models are able to capture important behaviour of phytoplankton, so we no longer need to go out to see or study phoyotplank in the lab.

# %% [markdown]
# ---------------------
# # Appendix: Why this would be a borderline fail assessment
#
# * The code does at least run, and most points are there in a sense.
# * Very little structure in writing.
# * No axis labelling whatsoever.
# * Minimal exploration and description.
# * Sloppy choices of presentation of figures.
# * Spelling and grammatical errors all over the place.
# * No referencing whatsoever.
# * Scientifically inaccurate statements.
#   - The numerical model is a representation of the world, no more, no less, so whatever statement in that excuse of a conclusion is certainly over-claiming.
